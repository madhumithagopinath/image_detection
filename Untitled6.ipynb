# %%
import torch


model = torch.hub.load('ultralytics/yolov5', 'yolov5x', pretrained=True)


model.conf = 0.1


img = 'final.jpg'

results = model(img, size=980)


results.show()
results.save()


results.print()
print(results.pandas().xyxy[0])
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2025-6-4 Python-3.11.12 torch-2.6.0+cu124 CPU
#
# Fusing layers...
# YOLOv5x summary: 444 layers, 86705005 parameters, 0 gradients, 205.5 GFLOPs
# Adding AutoShape...
# /root/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:906: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=231x244>
# Saved 1 image to runs/detect/exp9
# image 1/1: 244x231 2 bottles, 4 cups, 1 knife, 2 spoons, 1 tv, 1 book, 1 scissors, 3 toothbrushs
# Speed: 11.5ms pre-process, 8538.8ms inference, 3.2ms NMS per image at shape (1, 3, 992, 928)
#           xmin        ymin        xmax        ymax  confidence  class  \
# 0    63.820038   63.608204  123.546959  131.167999    0.664048     44
# 1    82.727898   13.732546  125.407852   64.502350    0.563737     41
# 2   132.645889   10.534858  171.491211   65.895309    0.531265     44
# 3    36.562630  185.168320   64.304337  220.679367    0.520136     79
# 4   117.597725   76.544220  150.608337  115.609322    0.369168     41
# 5   132.539993   10.046250  171.571259   65.955429    0.289507     41
# 6    13.637261   14.059912   71.539444   53.518898    0.269589     62
# 7   132.642059   10.263305  171.524796   65.829742    0.258501     76
# 8   161.282806   16.895979  211.927124   71.558250    0.222630     79
# 9    72.653938  159.777145   97.143242  209.756104    0.217784     39
# 10   14.396688  152.452774   60.876274  191.447815    0.191578     79
# 11  161.081787   16.843029  211.847092   71.769302    0.183117     43
# 12  183.516663   50.416409  219.350311   80.789337    0.162177     41
# 13    9.754678   80.359467   80.757011  122.602859    0.117944     73
# 14  127.699059  142.695419  140.907990  183.598038    0.109325     39
#
#           name
# 0        spoon
# 1          cup
# 2        spoon
# 3   toothbrush
# 4          cup
# 5          cup
# 6           tv
# 7     scissors
# 8   toothbrush
# 9       bottle
# 10  toothbrush
# 11       knife
# 12         cup
# 13        book
# 14      bottle
